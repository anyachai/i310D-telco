# %%
import matplotlib.pyplot as plt
import pandas as pd
import time

df = pd.read_csv('Telco-Customer-Churn.csv')

# %% [markdown]
# ### Table for all customers with Churn="Yes"

# %%
sub_df = df.loc[df['Churn']=='Yes']
sub_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %% [markdown]
# Out of the total 7044 customers Telco has data on, there are 1869 customers based on the table above that are no longer customers. Our next step, is to attempt to find any similiraties or reocurrences between the people who stop being customers and see if there are any trends.

# %% [markdown]
# ### Combination to find most propense people to leave Telco
#
# Now, I will combine the following conditions to find which group of people is more likely to stop being a Telco customer:
#
# - SeniorCitizen
# - Partner
# - Dependents
# - Tenure (of at least 12 months)
# - PhoneService
# - MultipleLines
# - InternetService

# %% [markdown]
# ### SeniorCitizen and Partner

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['Partner']== "Yes")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# 52    6575-SUVOI  Female              1     Yes         No      25
# 53    7495-OOKFY  Female              1     Yes         No       8
# 54    4667-QONEA  Female              1     Yes        Yes      60
# ...          ...     ...            ...     ...        ...     ...
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes           Yes     Fiber optic            Yes  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['Partner']== "Yes")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 8     7892-POOKP  Female              0     Yes         No      28
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 12    8091-TTVAX    Male              0     Yes         No      58
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['Partner']== "No")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# 55    1658-BYGOY    Male              1      No         No      18
# 75    2673-CXQEU  Female              1      No         No      56
# ...          ...     ...            ...     ...        ...     ...
# 6980  0786-VSSUD    Male              1      No         No      16
# 6987  5981-ZVXOT  Female              1      No         No      35
# 7008  1980-KXVPM  Female              1      No         No       3
# 7029  2235-DWLJU  Female              1      No         No       6
# 7032  6894-LFHLY    Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['Partner']== "No")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %% [markdown]
# ### SeniorCitizen and Dependents

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['Dependents']== "Yes")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK    Male              0      No        Yes      22
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 6             Yes               Yes     Fiber optic                   No  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['Dependents']== "Yes")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 72    1891-QRQSA    Male              1     Yes        Yes      64
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 308   3167-SNQPL    Male              1     Yes        Yes      38
# ...          ...     ...            ...     ...        ...     ...
# 6235  5180-UCIIQ    Male              1     Yes        Yes      22
# 6346  9661-MHUMO    Male              1     Yes        Yes       1
# 6446  2205-LPVGL    Male              1     Yes        Yes      58
# 6451  4868-AADLV    Male              1     Yes        Yes      66
# 6763  7471-MQPOS    Male              1     Yes        Yes      71
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 54            Yes                No             DSL            Yes  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['Dependents']== "No")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['Dependents']== "No")]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### SeniorCitizen and Tenure

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['tenure']>= 12)]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# ...          ...     ...            ...     ...        ...     ...
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['tenure']<= 12)]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7030  0871-OPBXW  Female              0      No         No       2
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['tenure']>= 12)]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female              1     Yes         No      71
# 50    8012-SOUDQ  Female              1      No         No      43
# 52    6575-SUVOI  Female              1     Yes         No      25
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 55    1658-BYGOY    Male              1      No         No      18
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 7007  2274-XUATA    Male              1     Yes         No      72
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7031  3605-JISKB    Male              1     Yes         No      55
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
df2=df.loc[(df['SeniorCitizen']== 1) & (df['tenure']<= 12)]
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 53    7495-OOKFY  Female              1     Yes         No       8
# 91    2424-WVHPL    Male              1      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 7008  1980-KXVPM  Female              1      No         No       3
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7029  2235-DWLJU  Female              1      No         No       6
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### SeniorCitizen and PhoneService

# %%
df2=df.loc[(df['SeniorCitizen']== 0) & (df['tenure']>= 12)]
df2
