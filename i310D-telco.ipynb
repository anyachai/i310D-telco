# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df[df['Churn']== 'Yes']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
 df[df['Churn']== 'Yes'] [df['gender']== 'Male']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/2676662761.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['gender']== 'Male']
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK   Male              0      No         No       2
# 13    0280-XJGEX   Male              0      No         No      49
# 20    8779-QRDMV   Male              1      No         No       1
# 22    1066-JKSGK   Male              0      No         No       1
# 26    6467-CHFZW   Male              0     Yes        Yes      47
# ...          ...    ...            ...     ...        ...     ...
# 7009  7703-ZEKEF   Male              0      No         No      23
# 7018  1122-JWTJW   Male              0     Yes        Yes       1
# 7021  1699-HPSBG   Male              0      No         No      12
# 7032  6894-LFHLY   Male              1      No         No       1
# ...

# %%
df[df['Churn']== 'Yes'] [df['Partner']== 'Yes']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/4165833816.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['Partner']== 'Yes']
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 53    7495-OOKFY  Female              1     Yes         No       8
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female              1     Yes         No      50
# 6996  4174-LPGTI  Female              0     Yes        Yes      41
# 7010  0723-DRCLG  Female              1     Yes         No       1
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# ...

# %%
df[df['Churn']== 'Yes'] [df['Partner']== 'No']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/3831325634.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['Partner']== 'No']
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 13    0280-XJGEX    Male              0      No         No      49
# 20    8779-QRDMV    Male              1      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 7011  5482-NUPNA  Female              0      No         No       4
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# ...

# %%
df[df['Churn']== 'Yes'] [df['Dependents']== 'No']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/1176828865.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['Dependents']== 'No']
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# ...

# %%
df[df['Churn']== 'Yes'] [df['Dependents']== 'Yes']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/2729976878.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['Dependents']== 'Yes']
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 80    5919-TMRGD  Female              0      No        Yes       1
# ...          ...     ...            ...     ...        ...     ...
# 6936  7693-LCKZL    Male              0     Yes        Yes       5
# 6943  0032-PGELS  Female              0     Yes        Yes       1
# 6945  6797-LNAQX    Male              0     Yes        Yes      70
# 6996  4174-LPGTI  Female              0     Yes        Yes      41
# ...

# %%
 df[df['Churn']== 'Yes'] [df['Partner']== 'No'] [df['Dependents']== 'No']
# Out:
# /var/folders/71/nhj7hvnd5w1dz46jndlg69_m0000gn/T/ipykernel_48862/1048653525.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Churn']== 'Yes'] [df['Partner']== 'No'] [df['Dependents']== 'No']
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 13    0280-XJGEX    Male              0      No         No      49
# 20    8779-QRDMV    Male              1      No         No       1
# ...          ...     ...            ...     ...        ...     ...
# 7011  5482-NUPNA  Female              0      No         No       4
# 7021  1699-HPSBG    Male              0      No         No      12
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# ...
